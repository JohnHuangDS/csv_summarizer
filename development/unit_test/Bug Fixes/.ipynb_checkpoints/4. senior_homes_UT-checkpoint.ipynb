# %%
import pandas as pd
import glob
import csv
import re
import numpy as np

# %%
extension = 'csv'

#grab all results with .csv
result = glob.glob('*.{}'.format(extension))
print(result)

#initilize output
with open('output/' +str(result[0]), 'w') as csvFile:
    csvFile.close()
print('output/'+str(result[0]) + " has been initialized")

#specify list of delimiters
delimiter_list = [';']

#read file
try:
    #try loading the csv
    df = pd.read_csv(result[0])

    #if it loads, check if one of these other delimiters is in the first column
    for items in delimiter_list:
        x = re.findall(items, df.columns[0])
        #if there is, read using that item
        if len(x) > 0:
            df = pd.read_csv(result[0], items)

except:
    #if the csv didnt load, try loading with delimiter
    for items in delimiter_list:
        #try reading with an item in the delimiter list
        try:
            df = pd.read_csv(result[0], items)
        except:
        #if it doesnt load, on to the next    
            pass
df.head()
# Out:
# ['seniors-homes.csv', 'translink-api-example.csv']
# output/seniors-homes.csv has been initialized
#     FID                 Name           Address  \
# 0   0.0      ALEXANDER HOUSE  176 Alexander St
# 1   5.0     BNAI BRITH MANOR      1260 Howe St
# 2   7.0      BROOKLAND COURT   540 Helmcken St
# 3   8.0  BRUCE ERIKSEN PLACE    380 Main Steet
# 4  10.0           CARL ROOMS    575 E Hastings
#
#                                Provider       LONG         LAT        POINT_X  \
# 0            Affordable Housing Society  49.284000 -123.099998  492708.509033
# 1            Bnai Brith Housing Society  49.277100 -123.127998  490690.602627
# 2                           127 Society  49.277100 -123.123001  491037.409892
# 3         Neighbourhood Housing Society  49.281601 -123.098999  492766.054383
# 4  Union Gospel Mission Housing Society  49.281300 -123.092003  493305.670907
#
#         POINT_Y
# 0  5.459027e+06
# 1  5.458267e+06
# 2  5.458268e+06
# 3  5.458765e+06
# 4  5.458736e+06

# %%
df
# Out:
#      Unnamed: 0                     Destination Direction   Latitude  \
# 0             0                       BLUERIDGE      EAST  49.305267
# 1             1                   METROTOWN STN      WEST  49.212083
# 2             2                       RIVERPORT      EAST  49.140700
# 3             3                             UBC      WEST  49.225050
# 4             4                             UBC      WEST  49.262383
# 5             5  BRIDGEPORT STN VIA LADNER EXCH     NORTH  49.006967
# 6             6                   METROTOWN STN      EAST  49.267567
# 7             7                   METROTOWN STN      EAST  49.234783
# 8             8                       BRAID STN      WEST  49.233033
# 9             9                      PT COQ STN      EAST  49.272100
# 10           10     PORT MANN EXP/CARVOLTH EXCH      EAST  49.215317
# 11           11      PORT MANN EXP/LOUGHEED STN      WEST  49.168733
# 12           12                      PT COQ STN      EAST  49.294650
# 13           13                MAPLE RIDGE EAST      EAST  49.220317
# 14           14                      SCOTTSDALE      EAST  49.118933
# 15           15                    LOUGHEED STN      EAST  49.202233
# 16           16                GUILDFORD B-LINE     NORTH  49.191450
# 17           17              NEWTON EXCH B-LINE     SOUTH  49.191600
# 18           18                    PT COQ SOUTH     SOUTH  49.260917
# 19           19                    CAPITOL HILL     NORTH  49.281050
# 20           20                           BEACH      WEST  49.274450
# 21           21                           BEACH      WEST  49.273233
# 22           22                     EDMONDS STN      EAST  49.189350
# 23           23                    NEW WEST STN      WEST  49.220467
# 24           24                          UPTOWN      EAST  49.207283
# 25           25                   VICTORIA HILL      EAST  49.199817
# 26           26                        UBC EXCH     NORTH  49.254617
# 27           27                   ROYAL OAK STN      WEST  49.212117
# 28           28                        QUAYSIDE      WEST  49.205517
# 380 -123.028633      E1  09:43:06 pm  https://nb.translink.ca/geodata/212.kmz
# 381 -123.024717      W1  09:38:14 pm  https://nb.translink.ca/geodata/209.kmz
# 382 -123.028217      W1  09:45:03 pm  https://nb.translink.ca/geodata/232.kmz
# 383 -123.120367      E1  09:45:31 pm  https://nb.translink.ca/geodata/209.kmz
# 384    0.000000      S1  09:46:57 pm  https://nb.translink.ca/geodata/130.kmz
#
#      RouteNo    TripId  VehicleNo
# 0        214  11153096      11302
# 1        147  10786035      11324
# 2        413  10808118      11325
# 3         49  10774670      12002
# 4         49  10774703      12012
# 5        620  10811881      12015
# 6         49  10774628      12019
# 7         49  10774587      12020
# 8        169  10788371      14006
# 9        160  10788052      14008
# 10       555  10809965      14012
# 11       555  10810010      14017
# 12       188  10791459      14020
# 13       701  10812470      14031
# 14       340  10802076      14041
# 15       101  10779361      14042
# 16        96  10777135      15005
# 17        96  10777245      15011
# 18       170  10788635       1507
# 19       132  10784076       1517
# 20        23  10770824       1518
# 21        23  10770832       1522
# 22       116  10781670       1525
# 23       105  10780234       1529
# 24       105  10780213       1530
# 25       103  10779712       1534
# 26        70  10775665       1536
# 27       148  10786260       1539
# 28       103  10779779       1542
# 29        23  10770719       1543
# ..       ...       ...        ...
# 355      402  10805235       9697
# 356        2  10820492       9698
# 357       22  10770253       9705
# 358       26  10771751       9708
# 359       29  10772691       9709
# 360       26  10771762       9710
# 361      209  10792015       9711
# 362       28  10772357       9716
# 363      239  10794811       9719
# 364      130  10783536       9729
# 365      228  10793479       9734
# 366      240  10795364       9736
# 367      239  10794864       9737
# 368      239  10794874       9738
# 369      228  10793518       9740
# 370      249  10826675       9741
# 371      240  10795381       9746
# 372      239  10794943       9748
# 373      230  10793987       9752
# 374      232  10794182       9756
# 375       27  10772091       9757
# 376      130  10783714       9758
# 377      130  10783719       9760
# 378      212  10792747       9765
# 379      229  10793758       9769
# 380      212  10792700       9771
# 381      209  10792014       9774
# 382      232  10794215       9782
# 383      209  10792000       9784
# 384      130  10783656       9791
#
# [385 rows x 11 columns]

# %%
# Check to see if the first column is Row ID
if df.columns[0] != 'Unnamed: 0':
    index =range(df.shape[0])
    df.insert(0, "Row #", index)

# %%
n_rows = df.shape[0]
n_columns = df.shape[1] - 1


with open('output/' +str(result[0]), 'a') as csvFile:

    #declare csv writer, delimiter = ' ' for writing stuff into a once cell
    writer = csv.writer(csvFile, delimiter = ' ')
    #excute a writerow command, can be list, dictionary, etc.

    #insert file name
    writer.writerow(['File Name : '+str(result[0])])
    #insert number of rows
    writer.writerow(["There are " +str(n_rows) + " rows"])
    #insert number of columns
    writer.writerow(["There are " +str(n_columns) + " columns"])
csvFile.close()
print('output/'+str(result[0]) +' has been updated with a title')

# %%
my_dict = {}
my_dict.update([(0, df.loc[0,:]),(1, df.loc[1,:])])
summary = pd.DataFrame.from_dict(my_dict)
summary = summary.T

# %%
with open('output/' +str(result[0]), 'a') as csvfile:
    fieldnames =summary.columns
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    #unpack dictionary
    for i in range(2):
        #declare dictionary
        dict1 = {}
        for items in summary.columns:
            #append items into dict1
            dict1.update([ (items, summary[items][i])])
        writer.writerow(dict1)
    writer_linebreak = csv.writer(csvfile, delimiter = ' ')
print('output/'+str(result[0]) +' has been updated with a summary')
